# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train = pd.read_csv("/content/drive/MyDrive/Zohreh/train.csv")
df_test = pd.read_csv("/content/drive/MyDrive/Zohreh/test.csv")
# Out:
# <ipython-input-885-e257f3d9e677>:1: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_train = pd.read_csv("/content/drive/MyDrive/Zohreh/train.csv")

# %%
df_train.head()
# Out:
#        ID Customer_ID     Month           Name   Age          SSN Occupation  \
# 0  0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265  Scientist
# 1  0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265  Scientist
# 2  0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265  Scientist
# 3  0x1605   CUS_0xd40     April  Aaron Maashoh    23  821-00-0265  Scientist
# 4  0x1606   CUS_0xd40       May  Aaron Maashoh    23  821-00-0265  Scientist
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0      19114.12            1824.843333                  3  ...           _
# 1      19114.12                    NaN                  3  ...        Good
# 2      19114.12                    NaN                  3  ...        Good
# 3      19114.12                    NaN                  3  ...        Good
# 4      19114.12            1824.843333                  3  ...        Good
#
#    Outstanding_Debt Credit_Utilization_Ratio     Credit_History_Age  \
# 0            809.98                26.822620  22 Years and 1 Months
# 1            809.98                31.944960                    NaN
# 2            809.98                28.609352  22 Years and 3 Months
# 3            809.98                31.377862  22 Years and 4 Months
# 4            809.98                24.797347  22 Years and 5 Months
#
#    Payment_of_Min_Amount Total_EMI_per_month Amount_invested_monthly  \
# 0                     No           49.574949       80.41529543900253
# 1                     No           49.574949      118.28022162236736
# 2                     No           49.574949         81.699521264648
# 3                     No           49.574949       199.4580743910713
# 4                     No           49.574949      41.420153086217326
#
#                   Payment_Behaviour     Monthly_Balance Credit_Score
# 0   High_spent_Small_value_payments  312.49408867943663         Good
# 1    Low_spent_Large_value_payments  284.62916249607184         Good
# 2   Low_spent_Medium_value_payments   331.2098628537912         Good
# 3    Low_spent_Small_value_payments  223.45130972736786         Good
# 4  High_spent_Medium_value_payments  341.48923103222177         Good
#
# [5 rows x 28 columns]

# %%
df_test.head()
# Out:
#        ID Customer_ID      Month             Name  Age          SSN  \
# 0  0x160a   CUS_0xd40  September    Aaron Maashoh   23  821-00-0265
# 1  0x160b   CUS_0xd40    October    Aaron Maashoh   24  821-00-0265
# 2  0x160c   CUS_0xd40   November    Aaron Maashoh   24  821-00-0265
# 3  0x160d   CUS_0xd40   December    Aaron Maashoh  24_  821-00-0265
# 4  0x1616  CUS_0x21b1  September  Rick Rothackerj   28  004-07-5839
#
#   Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 0  Scientist      19114.12            1824.843333                  3  ...
# 1  Scientist      19114.12            1824.843333                  3  ...
# 2  Scientist      19114.12            1824.843333                  3  ...
# 3  Scientist      19114.12                    NaN                  3  ...
# 4    _______      34847.84            3037.986667                  2  ...
#
#    Num_Credit_Inquiries  Credit_Mix Outstanding_Debt Credit_Utilization_Ratio  \
# 0                2022.0        Good           809.98                35.030402
# 1                   4.0        Good           809.98                33.053114
# 2                   4.0        Good           809.98                33.811894
# 3                   4.0        Good           809.98                32.430559
# 4                   5.0        Good           605.03                25.926822
#
#        Credit_History_Age Payment_of_Min_Amount Total_EMI_per_month  \
# 0   22 Years and 9 Months                    No           49.574949
# 1  22 Years and 10 Months                    No           49.574949
# 2                     NaN                    No           49.574949
# 3   23 Years and 0 Months                    No           49.574949
# 4   27 Years and 3 Months                    No           18.816215
#
#    Amount_invested_monthly                 Payment_Behaviour  \
# 0       236.64268203272135    Low_spent_Small_value_payments
# 1       21.465380264657146  High_spent_Medium_value_payments
# 2       148.23393788500925   Low_spent_Medium_value_payments
# 3        39.08251089460281  High_spent_Medium_value_payments
# 4       39.684018417945296   High_spent_Large_value_payments
#
#       Monthly_Balance
# 0  186.26670208571772
# 1  361.44400385378196
# 2  264.67544623342997
# 3  343.82687322383634
# 4   485.2984336755923
#
# [5 rows x 27 columns]

# %%
df_train.shape
# Out:
# (100000, 28)

# %%
df_test.shape
# Out:
# (50000, 27)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  object
#  1   Customer_ID               100000 non-null  object
#  2   Month                     100000 non-null  object
#  3   Name                      90015 non-null   object
#  4   Age                       100000 non-null  object
#  5   SSN                       100000 non-null  object
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  object
#  8   Monthly_Inhand_Salary     84998 non-null   float64
#  9   Num_Bank_Accounts         100000 non-null  int64
#  10  Num_Credit_Card           100000 non-null  int64
#  11  Interest_Rate             100000 non-null  int64
#  12  Num_of_Loan               100000 non-null  object
#  13  Type_of_Loan              88592 non-null   object
#  14  Delay_from_due_date       100000 non-null  int64
#  15  Num_of_Delayed_Payment    92998 non-null   object
#  16  Changed_Credit_Limit      100000 non-null  object
#  17  Num_Credit_Inquiries      98035 non-null   float64
#  18  Credit_Mix                100000 non-null  object
#  19  Outstanding_Debt          100000 non-null  object
#  20  Credit_Utilization_Ratio  100000 non-null  float64
#  21  Credit_History_Age        90970 non-null   object
#  22  Payment_of_Min_Amount     100000 non-null  object
#  23  Total_EMI_per_month       100000 non-null  float64
#  24  Amount_invested_monthly   95521 non-null   object
#  25  Payment_Behaviour         100000 non-null  object
#  26  Monthly_Balance           98800 non-null   object
#  27  Credit_Score              100000 non-null  object
# dtypes: float64(4), int64(4), object(20)
# memory usage: 21.4+ MB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        50000 non-null  object
#  1   Customer_ID               50000 non-null  object
#  2   Month                     50000 non-null  object
#  3   Name                      44985 non-null  object
#  4   Age                       50000 non-null  object
#  5   SSN                       50000 non-null  object
#  6   Occupation                50000 non-null  object
#  7   Annual_Income             50000 non-null  object
#  8   Monthly_Inhand_Salary     42502 non-null  float64
#  9   Num_Bank_Accounts         50000 non-null  int64
#  10  Num_Credit_Card           50000 non-null  int64
#  11  Interest_Rate             50000 non-null  int64
#  12  Num_of_Loan               50000 non-null  object
#  13  Type_of_Loan              44296 non-null  object
#  14  Delay_from_due_date       50000 non-null  int64
#  15  Num_of_Delayed_Payment    46502 non-null  object
#  16  Changed_Credit_Limit      50000 non-null  object
#  17  Num_Credit_Inquiries      48965 non-null  float64
#  18  Credit_Mix                50000 non-null  object
#  19  Outstanding_Debt          50000 non-null  object
#  20  Credit_Utilization_Ratio  50000 non-null  float64
#  21  Credit_History_Age        45530 non-null  object
#  22  Payment_of_Min_Amount     50000 non-null  object
#  23  Total_EMI_per_month       50000 non-null  float64
#  24  Amount_invested_monthly   47729 non-null  object
#  25  Payment_Behaviour         50000 non-null  object
#  26  Monthly_Balance           49438 non-null  object
# dtypes: float64(4), int64(4), object(19)
# memory usage: 10.3+ MB

# %%
df_train.describe()
# Out:
#        Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# count           84998.000000      100000.000000     100000.00000
# mean             4194.170850          17.091280         22.47443
# std              3183.686167         117.404834        129.05741
# min               303.645417          -1.000000          0.00000
# 25%              1625.568229           3.000000          4.00000
# 50%              3093.745000           6.000000          5.00000
# 75%              5957.448333           7.000000          7.00000
# max             15204.633333        1798.000000       1499.00000
#
#        Interest_Rate  Delay_from_due_date  Num_Credit_Inquiries  \
# count  100000.000000        100000.000000          98035.000000
# mean       72.466040            21.068780             27.754251
# std       466.422621            14.860104            193.177339
# min         1.000000            -5.000000              0.000000
# 25%         8.000000            10.000000              3.000000
# 50%        13.000000            18.000000              6.000000
# 75%        20.000000            28.000000              9.000000
# max      5797.000000            67.000000           2597.000000
#
#        Credit_Utilization_Ratio  Total_EMI_per_month
# count             100000.000000        100000.000000
# mean                  32.285173          1403.118217
# std                    5.116875          8306.041270
# min                   20.000000             0.000000
# 25%                   28.052567            30.306660
# 50%                   32.305784            69.249473
# 75%                   36.496663           161.224249
# max                   50.000000         82331.000000

# %%
df_test.describe()
# Out:
#        Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# count           42502.000000       50000.000000     50000.000000
# mean             4182.004291          16.838260        22.921480
# std              3174.109304         116.396848       129.314804
# min               303.645417          -1.000000         0.000000
# 25%              1625.188333           3.000000         4.000000
# 50%              3086.305000           6.000000         5.000000
# 75%              5934.189094           7.000000         7.000000
# max             15204.633333        1798.000000      1499.000000
#
#        Interest_Rate  Delay_from_due_date  Num_Credit_Inquiries  \
# count   50000.000000         50000.000000          48965.000000
# mean       68.772640            21.052640             30.080200
# std       451.602363            14.860397            196.984121
# min         1.000000            -5.000000              0.000000
# 25%         8.000000            10.000000              4.000000
# 50%        13.000000            18.000000              7.000000
# 75%        20.000000            28.000000             10.000000
# max      5799.000000            67.000000           2593.000000
#
#        Credit_Utilization_Ratio  Total_EMI_per_month
# count              50000.000000         50000.000000
# mean                  32.279581          1491.304305
# std                    5.106238          8595.647887
# min                   20.509652             0.000000
# 25%                   28.061040            32.222388
# 50%                   32.280390            74.733349
# 75%                   36.468591           176.157491
# max                   48.540663         82398.000000

# %%
df_train.describe(exclude =np.number).T
# Out:
#                           count  unique                               top  \
# ID                       100000  100000                            0x1602
# Customer_ID              100000   12500                         CUS_0xd40
# Month                    100000       8                           January
# Name                      90015   10139                            Langep
# Age                      100000    1788                                38
# SSN                      100000   12501                         #F%$D@*&8
# Occupation               100000      16                           _______
# Annual_Income            100000   18940                          36585.12
# Num_of_Loan              100000     434                                 3
# Type_of_Loan              88592    6260                     Not Specified
# Num_of_Delayed_Payment    92998     749                                19
# Changed_Credit_Limit     100000    4384                                 _
# Credit_Mix               100000       4                          Standard
# Outstanding_Debt         100000   13178                           1360.45
# Credit_History_Age        90970     404            15 Years and 11 Months
# Payment_of_Min_Amount    100000       3                               Yes
# Amount_invested_monthly   95521   91049                         __10000__
# Payment_Behaviour        100000       7    Low_spent_Small_value_payments
# Monthly_Balance           98800   98792  __-333333333333333333333333333__
# Credit_Score             100000       3                          Standard
#
#                           freq
# ID                           1
# Customer_ID                  8
# Month                    12500
# Name                        44
# Age                       2833
# SSN                       5572
# Occupation                7062
# Annual_Income               16
# Num_of_Loan              14386
# Type_of_Loan              1408
# Num_of_Delayed_Payment    5327
# Changed_Credit_Limit      2091
# Credit_Mix               36479
# Outstanding_Debt            24
# Credit_History_Age         446
# Payment_of_Min_Amount    52326
# Amount_invested_monthly   4305
# Payment_Behaviour        25513
# Monthly_Balance              9
# Credit_Score             53174

# %%
df_test.describe(exclude =np.number).T
# Out:
#                          count unique                               top   freq
# ID                       50000  50000                            0x160a      1
# Customer_ID              50000  12500                         CUS_0xd40      4
# Month                    50000      4                         September  12500
# Name                     44985  10139                            Stevex     22
# Age                      50000    976                                39   1493
# SSN                      50000  12501                         #F%$D@*&8   2828
# Occupation               50000     16                           _______   3438
# Annual_Income            50000  16121                         109945.32      8
# Num_of_Loan              50000    263                                 2   7173
# Type_of_Loan             44296   6260                     Not Specified    704
# Num_of_Delayed_Payment   46502    443                                19   2622
# Changed_Credit_Limit     50000   3927                                 _   1059
# Credit_Mix               50000      4                          Standard  18379
# Outstanding_Debt         50000  12685                           1109.03     12
# Credit_History_Age       45530    399             20 Years and 1 Months    254
# Payment_of_Min_Amount    50000      3                               Yes  26158
# Amount_invested_monthly  47729  45450                         __10000__   2175
# Payment_Behaviour        50000      7    Low_spent_Small_value_payments  12694
# Monthly_Balance          49438  49433  __-333333333333333333333333333__      6

# %%
df_train.isna().sum()
# Out:
# ID                              0
# Customer_ID                     0
# Month                           0
# Name                         9985
# Age                             0
# SSN                             0
# Occupation                      0
# Annual_Income                   0
# Monthly_Inhand_Salary       15002
# Num_Bank_Accounts               0
# Num_Credit_Card                 0
# Interest_Rate                   0
# Num_of_Loan                     0
# Type_of_Loan                11408
# Delay_from_due_date             0
# Num_of_Delayed_Payment       7002
# Changed_Credit_Limit            0
# Num_Credit_Inquiries         1965
# Credit_Mix                      0
# Outstanding_Debt                0
# Credit_Utilization_Ratio        0
# Credit_History_Age           9030
# Payment_of_Min_Amount           0
# Total_EMI_per_month             0
# Amount_invested_monthly      4479
# Payment_Behaviour               0
# Monthly_Balance              1200
# Credit_Score                    0
# dtype: int64

# %%
df_test.isna().sum()
# Out:
# ID                             0
# Customer_ID                    0
# Month                          0
# Name                        5015
# Age                            0
# SSN                            0
# Occupation                     0
# Annual_Income                  0
# Monthly_Inhand_Salary       7498
# Num_Bank_Accounts              0
# Num_Credit_Card                0
# Interest_Rate                  0
# Num_of_Loan                    0
# Type_of_Loan                5704
# Delay_from_due_date            0
# Num_of_Delayed_Payment      3498
# Changed_Credit_Limit           0
# Num_Credit_Inquiries        1035
# Credit_Mix                     0
# Outstanding_Debt               0
# Credit_Utilization_Ratio       0
# Credit_History_Age          4470
# Payment_of_Min_Amount          0
# Total_EMI_per_month            0
# Amount_invested_monthly     2271
# Payment_Behaviour              0
# Monthly_Balance              562
# dtype: int64

# %%
df_train.nunique()
# Out:
# ID                          100000
# Customer_ID                  12500
# Month                            8
# Name                         10139
# Age                           1788
# SSN                          12501
# Occupation                      16
# Annual_Income                18940
# Monthly_Inhand_Salary        13235
# Num_Bank_Accounts              943
# Num_Credit_Card               1179
# Interest_Rate                 1750
# Num_of_Loan                    434
# Type_of_Loan                  6260
# Delay_from_due_date             73
# Num_of_Delayed_Payment         749
# Changed_Credit_Limit          4384
# Num_Credit_Inquiries          1223
# Credit_Mix                       4
# Outstanding_Debt             13178
# Credit_Utilization_Ratio    100000
# Credit_History_Age             404
# Payment_of_Min_Amount            3
# Total_EMI_per_month          14950
# Amount_invested_monthly      91049
# Payment_Behaviour                7
# Monthly_Balance              98792
# Credit_Score                     3
# dtype: int64

# %%
df_train['Credit_Mix'].value_counts()
# Out:
# Standard    36479
# Good        24337
# _           20195
# Bad         18989
# Name: Credit_Mix, dtype: int64

# %%
# Drop irelevent columns

columns_to_drop = ["Name", "SSN", "ID"]

df_train.drop(columns=columns_to_drop, inplace=True)
df_test.drop(columns=columns_to_drop, inplace=True)

# %%
df_train.head().T
# Out:
#                                                                           0  \
# Customer_ID                                                       CUS_0xd40
# Month                                                               January
# Age                                                                      23
# Occupation                                                        Scientist
# Annual_Income                                                      19114.12
# Monthly_Inhand_Salary                                           1824.843333
# Num_Bank_Accounts                                                         3
# Num_Credit_Card                                                           4
# Interest_Rate                                                             3
# Num_of_Loan                                                               4
# Type_of_Loan              Auto Loan, Credit-Builder Loan, Personal Loan,...
# Delay_from_due_date                                                       3
# Num_of_Delayed_Payment                                                    7
# Changed_Credit_Limit                                                  11.27
# Num_Credit_Inquiries                                                    4.0
# Credit_Mix                                                                _
# Outstanding_Debt                                                     809.98
# Credit_Utilization_Ratio                                           26.82262
# Credit_History_Age                                    22 Years and 1 Months
# Payment_of_Min_Amount                                                    No
# Total_EMI_per_month                                               49.574949
# Amount_invested_monthly                                   80.41529543900253
# Payment_Behaviour                           High_spent_Small_value_payments
# Monthly_Balance                                          312.49408867943663
# Credit_Score                                                           Good
#
#                                                                           1  \
# Customer_ID                                                       CUS_0xd40
# Month                                                              February
# Age                                                                      23
# Occupation                                                        Scientist
# Annual_Income                                                      19114.12
# Monthly_Inhand_Salary                                                   NaN
# Num_Bank_Accounts                                                         3
# Num_Credit_Card                                                           4
# Interest_Rate                                                             3
# Num_of_Loan                                                               4
# Type_of_Loan              Auto Loan, Credit-Builder Loan, Personal Loan,...
# Delay_from_due_date                                                      -1
# Num_of_Delayed_Payment                                                  NaN
# Changed_Credit_Limit                                                  11.27
# Num_Credit_Inquiries                                                    4.0
# Credit_Mix                                                             Good
# Outstanding_Debt                                                     809.98
# Credit_Utilization_Ratio                                           31.94496
# Credit_History_Age                                                      NaN
# Payment_of_Min_Amount                                                    No
# Total_EMI_per_month                                               49.574949
# Amount_invested_monthly                                  118.28022162236736
# Payment_Behaviour                            Low_spent_Large_value_payments
# Monthly_Balance                                          284.62916249607184
# Credit_Score                                                           Good
#
#                                                                           2  \
# Customer_ID                                                       CUS_0xd40
# Month                                                                 March
# Age                                                                    -500
# Occupation                                                        Scientist
# Annual_Income                                                      19114.12
# Monthly_Inhand_Salary                                                   NaN
# Num_Bank_Accounts                                                         3
# Num_Credit_Card                                                           4
# Interest_Rate                                                             3
# Num_of_Loan                                                               4
# Type_of_Loan              Auto Loan, Credit-Builder Loan, Personal Loan,...
# Delay_from_due_date                                                       3
# Num_of_Delayed_Payment                                                    7
# Changed_Credit_Limit                                                      _
# Num_Credit_Inquiries                                                    4.0
# Credit_Mix                                                             Good
# Outstanding_Debt                                                     809.98
# Credit_Utilization_Ratio                                          28.609352
# Credit_History_Age                                    22 Years and 3 Months
# Payment_of_Min_Amount                                                    No
# Total_EMI_per_month                                               49.574949
# Amount_invested_monthly                                     81.699521264648
# Payment_Behaviour                           Low_spent_Medium_value_payments
# Monthly_Balance                                           331.2098628537912
# Credit_Score                                                           Good
#
#                                                                           3  \
# Customer_ID                                                       CUS_0xd40
# Month                                                                 April
# Age                                                                      23
# Occupation                                                        Scientist
# Annual_Income                                                      19114.12
# Monthly_Inhand_Salary                                                   NaN
# Num_Bank_Accounts                                                         3
# Num_Credit_Card                                                           4
# Interest_Rate                                                             3
# Num_of_Loan                                                               4
# Type_of_Loan              Auto Loan, Credit-Builder Loan, Personal Loan,...
# Delay_from_due_date                                                       5
# Num_of_Delayed_Payment                                                    4
# Changed_Credit_Limit                                                   6.27
# Num_Credit_Inquiries                                                    4.0
# Credit_Mix                                                             Good
# Outstanding_Debt                                                     809.98
# Credit_Utilization_Ratio                                          31.377862
# Credit_History_Age                                    22 Years and 4 Months
# Payment_of_Min_Amount                                                    No
# Total_EMI_per_month                                               49.574949
# Amount_invested_monthly                                   199.4580743910713
# Payment_Behaviour                            Low_spent_Small_value_payments
# Monthly_Balance                                          223.45130972736786
# Credit_Score                                                           Good
#
#                                                                           4
# Customer_ID                                                       CUS_0xd40
# Month                                                                   May
# Age                                                                      23
# Occupation                                                        Scientist
# Annual_Income                                                      19114.12
# Monthly_Inhand_Salary                                           1824.843333
# Num_Bank_Accounts                                                         3
# Num_Credit_Card                                                           4
# Interest_Rate                                                             3
# Num_of_Loan                                                               4
# Type_of_Loan              Auto Loan, Credit-Builder Loan, Personal Loan,...
# Delay_from_due_date                                                       6
# Num_of_Delayed_Payment                                                  NaN
# Changed_Credit_Limit                                                  11.27
# Num_Credit_Inquiries                                                    4.0
# Credit_Mix                                                             Good
# Outstanding_Debt                                                     809.98
# Credit_Utilization_Ratio                                          24.797347
# Credit_History_Age                                    22 Years and 5 Months
# Payment_of_Min_Amount                                                    No
# Total_EMI_per_month                                               49.574949
# Amount_invested_monthly                                  41.420153086217326
# Payment_Behaviour                          High_spent_Medium_value_payments
# Monthly_Balance                                          341.48923103222177
# Credit_Score                                                           Good

# %%
df_test.head().T
# Out:
#                                                                           0  \
# Customer_ID                                                       CUS_0xd40
# Month                                                             September
# Age                                                                      23
# Occupation                                                        Scientist
# Annual_Income                                                      19114.12
# Monthly_Inhand_Salary                                           1824.843333
# Num_Bank_Accounts                                                         3
# Num_Credit_Card                                                           4
# Interest_Rate                                                             3
# Num_of_Loan                                                               4
# Type_of_Loan              Auto Loan, Credit-Builder Loan, Personal Loan,...
# Delay_from_due_date                                                       3
# Num_of_Delayed_Payment                                                    7
# Changed_Credit_Limit                                                  11.27
# Num_Credit_Inquiries                                                 2022.0
# Credit_Mix                                                             Good
# Outstanding_Debt                                                     809.98
# Credit_Utilization_Ratio                                          35.030402
# Credit_History_Age                                    22 Years and 9 Months
# Payment_of_Min_Amount                                                    No
# Total_EMI_per_month                                               49.574949
# Amount_invested_monthly                                  236.64268203272135
# Payment_Behaviour                            Low_spent_Small_value_payments
# Monthly_Balance                                          186.26670208571772
#
#                                                                           1  \
# Customer_ID                                                       CUS_0xd40
# Month                                                               October
# Age                                                                      24
# Occupation                                                        Scientist
# Annual_Income                                                      19114.12
# Monthly_Inhand_Salary                                           1824.843333
# Num_Bank_Accounts                                                         3
# Num_Credit_Card                                                           4
# Interest_Rate                                                             3
# Num_of_Loan                                                               4
# Type_of_Loan              Auto Loan, Credit-Builder Loan, Personal Loan,...
# Delay_from_due_date                                                       3
# Num_of_Delayed_Payment                                                    9
# Changed_Credit_Limit                                                  13.27
# Num_Credit_Inquiries                                                    4.0
# Credit_Mix                                                             Good
# Outstanding_Debt                                                     809.98
# Credit_Utilization_Ratio                                          33.053114
# Credit_History_Age                                   22 Years and 10 Months
# Payment_of_Min_Amount                                                    No
# Total_EMI_per_month                                               49.574949
# Amount_invested_monthly                                  21.465380264657146
# Payment_Behaviour                          High_spent_Medium_value_payments
# Monthly_Balance                                          361.44400385378196
#
#                                                                           2  \
# Customer_ID                                                       CUS_0xd40
# Month                                                              November
# Age                                                                      24
# Occupation                                                        Scientist
# Annual_Income                                                      19114.12
# Monthly_Inhand_Salary                                           1824.843333
# Num_Bank_Accounts                                                         3
# Num_Credit_Card                                                           4
# Interest_Rate                                                             3
# Num_of_Loan                                                               4
# Type_of_Loan              Auto Loan, Credit-Builder Loan, Personal Loan,...
# Delay_from_due_date                                                      -1
# Num_of_Delayed_Payment                                                    4
# Changed_Credit_Limit                                                  12.27
# Num_Credit_Inquiries                                                    4.0
# Credit_Mix                                                             Good
# Outstanding_Debt                                                     809.98
# Credit_Utilization_Ratio                                          33.811894
# Credit_History_Age                                                      NaN
# Payment_of_Min_Amount                                                    No
# Total_EMI_per_month                                               49.574949
# Amount_invested_monthly                                  148.23393788500925
# Payment_Behaviour                           Low_spent_Medium_value_payments
# Monthly_Balance                                          264.67544623342997
#
#                                                                           3  \
# Customer_ID                                                       CUS_0xd40
# Month                                                              December
# Age                                                                     24_
# Occupation                                                        Scientist
# Annual_Income                                                      19114.12
# Monthly_Inhand_Salary                                                   NaN
# Num_Bank_Accounts                                                         3
# Num_Credit_Card                                                           4
# Interest_Rate                                                             3
# Num_of_Loan                                                               4
# Type_of_Loan              Auto Loan, Credit-Builder Loan, Personal Loan,...
# Delay_from_due_date                                                       4
# Num_of_Delayed_Payment                                                    5
# Changed_Credit_Limit                                                  11.27
# Num_Credit_Inquiries                                                    4.0
# Credit_Mix                                                             Good
# Outstanding_Debt                                                     809.98
# Credit_Utilization_Ratio                                          32.430559
# Credit_History_Age                                    23 Years and 0 Months
# Payment_of_Min_Amount                                                    No
# Total_EMI_per_month                                               49.574949
# Amount_invested_monthly                                   39.08251089460281
# Payment_Behaviour                          High_spent_Medium_value_payments
# Monthly_Balance                                          343.82687322383634
#
#                                                         4
# Customer_ID                                    CUS_0x21b1
# Month                                           September
# Age                                                    28
# Occupation                                        _______
# Annual_Income                                    34847.84
# Monthly_Inhand_Salary                         3037.986667
# Num_Bank_Accounts                                       2
# Num_Credit_Card                                         4
# Interest_Rate                                           6
# Num_of_Loan                                             1
# Type_of_Loan                          Credit-Builder Loan
# Delay_from_due_date                                     3
# Num_of_Delayed_Payment                                  1
# Changed_Credit_Limit                                 5.42
# Num_Credit_Inquiries                                  5.0
# Credit_Mix                                           Good
# Outstanding_Debt                                   605.03
# Credit_Utilization_Ratio                        25.926822
# Credit_History_Age                  27 Years and 3 Months
# Payment_of_Min_Amount                                  No
# Total_EMI_per_month                             18.816215
# Amount_invested_monthly                39.684018417945296
# Payment_Behaviour         High_spent_Large_value_payments
# Monthly_Balance                         485.2984336755923

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Customer_ID               100000 non-null  object
#  1   Month                     100000 non-null  object
#  2   Age                       100000 non-null  object
#  3   Occupation                100000 non-null  object
#  4   Annual_Income             100000 non-null  object
#  5   Monthly_Inhand_Salary     84998 non-null   float64
#  6   Num_Bank_Accounts         100000 non-null  int64
#  7   Num_Credit_Card           100000 non-null  int64
#  8   Interest_Rate             100000 non-null  int64
#  9   Num_of_Loan               100000 non-null  object
#  10  Type_of_Loan              88592 non-null   object
#  11  Delay_from_due_date       100000 non-null  int64
#  12  Num_of_Delayed_Payment    92998 non-null   object
#  13  Changed_Credit_Limit      100000 non-null  object
#  14  Num_Credit_Inquiries      98035 non-null   float64
#  15  Credit_Mix                100000 non-null  object
#  16  Outstanding_Debt          100000 non-null  object
#  17  Credit_Utilization_Ratio  100000 non-null  float64
#  18  Credit_History_Age        90970 non-null   object
#  19  Payment_of_Min_Amount     100000 non-null  object
#  20  Total_EMI_per_month       100000 non-null  float64
#  21  Amount_invested_monthly   95521 non-null   object
#  22  Payment_Behaviour         100000 non-null  object
#  23  Monthly_Balance           98800 non-null   object
#  24  Credit_Score              100000 non-null  object
# dtypes: float64(4), int64(4), object(17)
# memory usage: 19.1+ MB

# %%
df_train['Month'].value_counts()
# Out:
# January     12500
# February    12500
# March       12500
# April       12500
# May         12500
# June        12500
# July        12500
# August      12500
# Name: Month, dtype: int64

# %%
# Convert "Month" column to numerical format
df_train['Month'] = pd.to_datetime(df_train['Month'], format='%B', errors='coerce').dt.month
df_test['Month'] = pd.to_datetime(df_test['Month'], format='%B', errors='coerce').dt.month

# %%
df_train.tail()
# Out:
#       Customer_ID  Month Age Occupation Annual_Income  Monthly_Inhand_Salary  \
# 99995  CUS_0x942c      4  25   Mechanic      39628.99            3359.415833
# 99996  CUS_0x942c      5  25   Mechanic      39628.99            3359.415833
# 99997  CUS_0x942c      6  25   Mechanic      39628.99            3359.415833
# 99998  CUS_0x942c      7  25   Mechanic      39628.99            3359.415833
# 99999  CUS_0x942c      8  25   Mechanic     39628.99_            3359.415833
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate Num_of_Loan  ...  \
# 99995                  4                6              7           2  ...
# 99996                  4                6              7           2  ...
# 99997                  4                6           5729           2  ...
# 99998                  4                6              7           2  ...
# 99999                  4                6              7           2  ...
#
#       Credit_Mix  Outstanding_Debt Credit_Utilization_Ratio  \
# 99995          _            502.38                34.663572
# 99996          _            502.38                40.565631
# 99997       Good            502.38                41.255522
# 99998       Good            502.38                33.638208
# 99999       Good            502.38                34.192463
#
#            Credit_History_Age  Payment_of_Min_Amount Total_EMI_per_month  \
# 99995   31 Years and 6 Months                     No           35.104023
# 99996   31 Years and 7 Months                     No           35.104023
# 99997   31 Years and 8 Months                     No           35.104023
# 99998   31 Years and 9 Months                     No           35.104023
# 99999  31 Years and 10 Months                     No           35.104023
#
#       Amount_invested_monthly                 Payment_Behaviour  \
# 99995       60.97133255718485   High_spent_Large_value_payments
# 99996       54.18595028760385  High_spent_Medium_value_payments
# 99997       24.02847744864441   High_spent_Large_value_payments
# 99998      251.67258219721603    Low_spent_Large_value_payments
# 99999       167.1638651610451                            !@9#%8
#
#       Monthly_Balance Credit_Score
# 99995      479.866228         Poor
# 99996       496.65161         Poor
# 99997      516.809083         Poor
# 99998      319.164979     Standard
# 99999      393.673696         Poor
#
# [5 rows x 25 columns]

# %%
df_train['Customer_ID'].nunique()
# Out:
# 12500

# %%
df_train['Age'].head(10)
# Out:
# 0      23
# 1      23
# 2    -500
# 3      23
# 4      23
# 5      23
# 6      23
# 7      23
# 8     28_
# 9      28
# Name: Age, dtype: object

# %%
# Remove non-numeric characters from "Age" column
df_train['Age'] = df_train['Age'].str.replace(r'[^0-9-]', '', regex=True)
df_test['Age'] = df_test['Age'].str.replace(r'[^0-9-]', '', regex=True)

# Convert "Age" column to numeric
df_train['Age'] = pd.to_numeric(df_train['Age'], errors='coerce').astype('Int64')
df_test['Age'] = pd.to_numeric(df_test['Age'], errors='coerce').astype('Int64')

# Make negative values in "Age" column positive
df_train['Age'] = df_train['Age'].abs()
df_test['Age'] = df_test['Age'].abs()

# Replace ages greater than 75 with NaN
df_train['Age'] = df_train['Age'].apply(lambda x: x if 0 <= x <= 75 else np.nan)
df_test['Age'] = df_test['Age'].apply(lambda x: x if 0 <= x <= 75 else np.nan)

# Drop rows with NaN values in the "Age" column
df_train = df_train.dropna(subset=['Age']).reset_index(drop=True)
df_test = df_test.dropna(subset=['Age']).reset_index(drop=True)

# %%
df_train['Age'].head(10)
# Out:
# 0    23.0
# 1    23.0
# 2    23.0
# 3    23.0
# 4    23.0
# 5    23.0
# 6    23.0
# 7    28.0
# 8    28.0
# 9    28.0
# Name: Age, dtype: float64

# %%
df_train['Occupation'].nunique()
# Out:
# 16

# %%
# Replace NaN values in the "Occupation" "Type_of_Loan" "Credit_Mix" column with ""
df_train['Occupation'].fillna("", inplace=True)
df_test['Occupation'].fillna("", inplace=True)

df_train['Type_of_Loan'].fillna("Not Specified", inplace=True)
df_test['Type_of_Loan'].fillna("Not Specified", inplace=True)

df_train['Credit_Mix'].fillna("", inplace=True)
df_test['Credit_Mix'].fillna("", inplace=True)

# %%
df_train['Num_Bank_Accounts'].value_counts()
# Out:
# 6       12629
# 7       12473
# 8       12437
# 4       11837
# 5       11796
#         ...
# 1470        1
# 211         1
# 1221        1
# 753         1
# 697         1
# Name: Num_Bank_Accounts, Length: 925, dtype: int64

# %%
df_train['Num_Bank_Accounts'].nunique()
# Out:
# 925

# %%
df_train['Num_Bank_Accounts'].describe()
# Out:
# count    97219.000000
# mean        17.128658
# std        117.690107
# min         -1.000000
# 25%          3.000000
# 50%          6.000000
# 75%          7.000000
# max       1798.000000
# Name: Num_Bank_Accounts, dtype: float64

# %%
# Replace values less than 0 in "Num_Bank_Accounts" with 0
df_train['Num_Bank_Accounts'] = df_train['Num_Bank_Accounts'].apply(lambda x: max(0, x))
df_test['Num_Bank_Accounts'] = df_test['Num_Bank_Accounts'].apply(lambda x: max(0, x))

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97219 entries, 0 to 97218
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer_ID               97219 non-null  object
#  1   Month                     97219 non-null  int64
#  2   Age                       97219 non-null  float64
#  3   Occupation                97219 non-null  object
#  4   Annual_Income             97219 non-null  object
#  5   Monthly_Inhand_Salary     82623 non-null  float64
#  6   Num_Bank_Accounts         97219 non-null  int64
#  7   Num_Credit_Card           97219 non-null  int64
#  8   Interest_Rate             97219 non-null  int64
#  9   Num_of_Loan               97219 non-null  object
#  10  Type_of_Loan              97219 non-null  object
#  11  Delay_from_due_date       97219 non-null  int64
#  12  Num_of_Delayed_Payment    90395 non-null  object
#  13  Changed_Credit_Limit      97219 non-null  object
#  14  Num_Credit_Inquiries      95313 non-null  float64
#  15  Credit_Mix                97219 non-null  object
#  16  Outstanding_Debt          97219 non-null  object
#  17  Credit_Utilization_Ratio  97219 non-null  float64
#  18  Credit_History_Age        88428 non-null  object
#  19  Payment_of_Min_Amount     97219 non-null  object
#  20  Total_EMI_per_month       97219 non-null  float64
#  21  Amount_invested_monthly   92875 non-null  object
#  22  Payment_Behaviour         97219 non-null  object
#  23  Monthly_Balance           96040 non-null  object
#  24  Credit_Score              97219 non-null  object
# dtypes: float64(5), int64(5), object(15)
# memory usage: 18.5+ MB

# %%
# Drop "Customer_ID" column
df_train.drop(columns=['Customer_ID'], inplace=True)
df_test.drop(columns=['Customer_ID'], inplace=True)

# %%
df_train['Occupation'].nunique()
# Out:
# 16

# %%
df_train['Occupation'].value_counts()
# Out:
# _______          6872
# Lawyer           6389
# Architect        6175
# Engineer         6171
# Scientist        6113
# Accountant       6110
# Mechanic         6099
# Media_Manager    6068
# Teacher          6049
# Developer        6031
# Entrepreneur     6014
# Doctor           5915
# Journalist       5906
# Manager          5806
# Musician         5760
# Writer           5741
# Name: Occupation, dtype: int64

# %%
# Replace "_______" with "Not Specified" in the Occupation column
df_train['Occupation'].replace("_______", "Not Specified", inplace=True)
df_test['Occupation'].replace("_______", "Not Specified", inplace=True)

# %%
df_train['Occupation'].value_counts()
# Out:
# Not Specified    6872
# Lawyer           6389
# Architect        6175
# Engineer         6171
# Scientist        6113
# Accountant       6110
# Mechanic         6099
# Media_Manager    6068
# Teacher          6049
# Developer        6031
# Entrepreneur     6014
# Doctor           5915
# Journalist       5906
# Manager          5806
# Musician         5760
# Writer           5741
# Name: Occupation, dtype: int64

# %%
df_train['Annual_Income'].describe()
# Out:
# count        97219
# unique       18812
# top       20867.67
# freq            16
# Name: Annual_Income, dtype: object

# %%
# Remove leading and trailing underscores from "Annual_Income" column
df_train['Annual_Income'] = df_train['Annual_Income'].str.replace('_', '')
df_test['Annual_Income'] = df_test['Annual_Income'].str.replace('_', '')

# Convert "Annual_Income" column to numeric
df_train['Annual_Income'] = pd.to_numeric(df_train['Annual_Income'], errors='coerce')
df_test['Annual_Income'] = pd.to_numeric(df_test['Annual_Income'], errors='coerce')

# %%
df_train.tail()
# Out:
#        Month   Age Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 97214      4  25.0   Mechanic       39628.99            3359.415833
# 97215      5  25.0   Mechanic       39628.99            3359.415833
# 97216      6  25.0   Mechanic       39628.99            3359.415833
# 97217      7  25.0   Mechanic       39628.99            3359.415833
# 97218      8  25.0   Mechanic       39628.99            3359.415833
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate Num_of_Loan  \
# 97214                  4                6              7           2
# 97215                  4                6              7           2
# 97216                  4                6           5729           2
# 97217                  4                6              7           2
# 97218                  4                6              7           2
#
#                       Type_of_Loan  ...  Credit_Mix Outstanding_Debt  \
# 97214  Auto Loan, and Student Loan  ...           _           502.38
# 97215  Auto Loan, and Student Loan  ...           _           502.38
# 97216  Auto Loan, and Student Loan  ...        Good           502.38
# 97217  Auto Loan, and Student Loan  ...        Good           502.38
# 97218  Auto Loan, and Student Loan  ...        Good           502.38
#
#       Credit_Utilization_Ratio      Credit_History_Age Payment_of_Min_Amount  \
# 97214                34.663572   31 Years and 6 Months                    No
# 97215                40.565631   31 Years and 7 Months                    No
# 97216                41.255522   31 Years and 8 Months                    No
# 97217                33.638208   31 Years and 9 Months                    No
# 97218                34.192463  31 Years and 10 Months                    No
#
#       Total_EMI_per_month  Amount_invested_monthly  \
# 97214           35.104023        60.97133255718485
# 97215           35.104023        54.18595028760385
# 97216           35.104023        24.02847744864441
# 97217           35.104023       251.67258219721603
# 97218           35.104023        167.1638651610451
#
#                       Payment_Behaviour Monthly_Balance  Credit_Score
# 97214   High_spent_Large_value_payments      479.866228          Poor
# 97215  High_spent_Medium_value_payments       496.65161          Poor
# 97216   High_spent_Large_value_payments      516.809083          Poor
# 97217    Low_spent_Large_value_payments      319.164979      Standard
# 97218                            !@9#%8      393.673696          Poor
#
# [5 rows x 24 columns]

# %%
df_train['Num_of_Loan'].describe()
# Out:
# count     97219
# unique      418
# top           3
# freq      13986
# Name: Num_of_Loan, dtype: object

# %%
df_train['Num_of_Loan'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 97219 entries, 0 to 97218
# Series name: Num_of_Loan
# Non-Null Count  Dtype
# --------------  -----
# 97219 non-null  object
# dtypes: object(1)
# memory usage: 759.6+ KB

# %%
# Convert "Num_of_Loan" column to numeric and then to integers, replacing NaN with 0
df_train['Num_of_Loan'] = pd.to_numeric(df_train['Num_of_Loan'], errors='coerce').astype('Int64').fillna(0)
df_test['Num_of_Loan'] = pd.to_numeric(df_test['Num_of_Loan'], errors='coerce').astype('Int64').fillna(0)

# %%
print(df_train['Num_of_Loan'].isna().sum())
print(df_test['Num_of_Loan'].isna().sum())
# Out:
# 0
# 0

# %%
print(df_train['Num_of_Delayed_Payment'].isna().sum())
print(df_test['Num_of_Delayed_Payment'].isna().sum())
# Out:
# 6824
# 3403

# %%
# Remove non-numeric characters from "Num_of_Delayed_Payment" column
df_train['Num_of_Delayed_Payment'] = df_train['Num_of_Delayed_Payment'].str.replace(r'\D', '', regex=True)
df_test['Num_of_Delayed_Payment'] = df_test['Num_of_Delayed_Payment'].str.replace(r'\D', '', regex=True)

# Fill NaN values with 0 and convert the column to integers
df_train['Num_of_Delayed_Payment'] = pd.to_numeric(df_train['Num_of_Delayed_Payment'], errors='coerce').fillna(0).astype('Int64')
df_test['Num_of_Delayed_Payment'] = pd.to_numeric(df_test['Num_of_Delayed_Payment'], errors='coerce').fillna(0).astype('Int64')

# %%
# Remove non-numeric characters from "Changed_Credit_Limit" column
df_train['Changed_Credit_Limit'] = df_train['Changed_Credit_Limit'].str.replace(r'\D', '', regex=True)
df_test['Changed_Credit_Limit'] = df_test['Changed_Credit_Limit'].str.replace(r'\D', '', regex=True)

# Replace empty strings with 0 before converting to float

df_train['Changed_Credit_Limit'] = pd.to_numeric(df_train['Changed_Credit_Limit'], errors='coerce').fillna(0).astype('float64')
df_test['Changed_Credit_Limit'] = pd.to_numeric(df_test['Changed_Credit_Limit'], errors='coerce').fillna(0).astype('float64')

# %%
# Drop rows with missing values in 'Monthly_Inhand_Salary' column
df_train = df_train.dropna(subset=['Monthly_Inhand_Salary']).reset_index(drop=True)
df_test = df_test.dropna(subset=['Monthly_Inhand_Salary']).reset_index(drop=True)

# %%
# Fill missing values with 0 for 'Num_Credit_Inquiries' column
df_train['Num_Credit_Inquiries'] = df_train['Num_Credit_Inquiries'].fillna(0)
df_test['Num_Credit_Inquiries'] = df_test['Num_Credit_Inquiries'].fillna(0)

# %%
df_train['Credit_Mix'].value_counts()
# Out:
# Standard    30205
# Good        20010
# _           16675
# Bad         15733
# Name: Credit_Mix, dtype: int64

# %%
# Replace '_' with 'Not Specified' in 'Credit_Mix' column
df_train['Credit_Mix'] = df_train['Credit_Mix'].replace('_', 'Not Specified')

# %%
df_train['Outstanding_Debt'].head(20)
# Out:
# 0      809.98
# 1      809.98
# 2      809.98
# 3      809.98
# 4      605.03
# 5      605.03
# 6      605.03
# 7      605.03
# 8      605.03
# 9      605.03
# 10    1303.01
# 11    1303.01
# 12    1303.01
# 13    1303.01
# 14    1303.01
# 15    1303.01
# 16    1303.01
# 17     632.46
# 18     632.46
# 19     632.46
# Name: Outstanding_Debt, dtype: object

# %%
# Remove non-numeric characters except decimal point from "Outstanding_Debt" column
df_train['Outstanding_Debt'] = df_train['Outstanding_Debt'].str.replace(r'[^0-9.]', '', regex=True)
df_test['Outstanding_Debt'] = df_test['Outstanding_Debt'].str.replace(r'[^0-9.]', '', regex=True)

# Replace empty strings with 0 before converting to float
df_train['Outstanding_Debt'] = pd.to_numeric(df_train['Outstanding_Debt'], errors='coerce').fillna(0)
df_test['Outstanding_Debt'] = pd.to_numeric(df_test['Outstanding_Debt'], errors='coerce').fillna(0)

# %%
df_train['Outstanding_Debt'].head(20)
# Out:
# 0      809.98
# 1      809.98
# 2      809.98
# 3      809.98
# 4      605.03
# 5      605.03
# 6      605.03
# 7      605.03
# 8      605.03
# 9      605.03
# 10    1303.01
# 11    1303.01
# 12    1303.01
# 13    1303.01
# 14    1303.01
# 15    1303.01
# 16    1303.01
# 17     632.46
# 18     632.46
# 19     632.46
# Name: Outstanding_Debt, dtype: float64

# %%
df_train['Credit_History_Age'].value_counts()
# Out:
# 15 Years and 9 Months     372
# 15 Years and 11 Months    367
# 19 Years and 3 Months     363
# 17 Years and 9 Months     361
# 17 Years and 11 Months    360
#                          ...
# 0 Years and 4 Months       27
# 0 Years and 3 Months       15
# 33 Years and 7 Months      13
# 0 Years and 2 Months       12
# 33 Years and 8 Months      11
# Name: Credit_History_Age, Length: 403, dtype: int64

# %%
df_train['Credit_History_Age'].describe()
# Out:
# count                     75127
# unique                      403
# top       15 Years and 9 Months
# freq                        372
# Name: Credit_History_Age, dtype: object

# %%
df_train['Credit_History_Age'].head()
# Out:
# 0    22 Years and 1 Months
# 1    22 Years and 5 Months
# 2    22 Years and 7 Months
# 3                      NaN
# 4    26 Years and 7 Months
# Name: Credit_History_Age, dtype: object

# %%
# Extract years and months
df_train['Years'] = df_train['Credit_History_Age'].str.extract(r'(\d+) Years').astype('float64')
df_train['Months'] = df_train['Credit_History_Age'].str.extract(r'(\d+) Months').astype('float64')

df_test['Years'] = df_test['Credit_History_Age'].str.extract(r'(\d+) Years').astype('float64')
df_test['Months'] = df_test['Credit_History_Age'].str.extract(r'(\d+) Months').astype('float64')


# Convert years to months and add to months
df_train['Credit_History_Age_Months'] = df_train['Years'] * 12 + df_train['Months']
df_test['Credit_History_Age_Months'] = df_test['Years'] * 12 + df_test['Months']

# Drop intermediate columns
df_train = df_train.drop(['Years', 'Months', 'Credit_History_Age'], axis=1)
df_test = df_test.drop(['Years', 'Months', 'Credit_History_Age'], axis=1)


# Replace NaN values with 0 and convert to Int64
df_train['Credit_History_Age_Months'] = df_train['Credit_History_Age_Months'].fillna(0).astype('Int64')
df_test['Credit_History_Age_Months'] = df_test['Credit_History_Age_Months'].fillna(0).astype('Int64')

# %%
df_train['Credit_History_Age_Months'].head()
# Out:
# 0    265
# 1    269
# 2    271
# 3      0
# 4    319
# Name: Credit_History_Age_Months, dtype: Int64

# %%
df_train['Amount_invested_monthly'].isna().sum()
# Out:
# 3649

# %%
df_train['Amount_invested_monthly'].head()
# Out:
# 0     80.41529543900253
# 1    41.420153086217326
# 2     178.3440674122349
# 3    24.785216509052056
# 4      104.291825168246
# Name: Amount_invested_monthly, dtype: object

# %%
# Convert "Amount_invested_monthly" to float
df_train['Amount_invested_monthly'] = pd.to_numeric(df_train['Amount_invested_monthly'], errors='coerce').astype('float64')
df_test['Amount_invested_monthly'] = pd.to_numeric(df_test['Amount_invested_monthly'], errors='coerce').astype('float64')

# Replace NaN values with 0
df_train['Amount_invested_monthly'].fillna(0, inplace=True)
df_test['Amount_invested_monthly'].fillna(0, inplace=True)

# %%
df_train['Amount_invested_monthly'].head()
# Out:
# 0     80.415295
# 1     41.420153
# 2    178.344067
# 3     24.785217
# 4    104.291825
# Name: Amount_invested_monthly, dtype: float64

# %%
df_train['Monthly_Balance'].isna().sum()
# Out:
# 1012

# %%
df_train['Monthly_Balance'].head()
# Out:
# 0    312.49408867943663
# 1    341.48923103222177
# 2     244.5653167062043
# 3    358.12416760938714
# 4    470.69062692529184
# Name: Monthly_Balance, dtype: object

# %%
# Convert "Amount_invested_monthly" to float
df_train['Monthly_Balance'] = pd.to_numeric(df_train['Monthly_Balance'], errors='coerce').astype('float64')
df_test['Monthly_Balance'] = pd.to_numeric(df_test['Monthly_Balance'], errors='coerce').astype('float64')

# Replace NaN values with 0
df_train['Monthly_Balance'].fillna(0, inplace=True)
df_test['Monthly_Balance'].fillna(0, inplace=True)

# %%
df_train['Monthly_Balance'].head()
# Out:
# 0    312.494089
# 1    341.489231
# 2    244.565317
# 3    358.124168
# 4    470.690627
# Name: Monthly_Balance, dtype: float64

# %%
df_train['Payment_Behaviour'].value_counts()
# Out:
# Low_spent_Small_value_payments      21194
# High_spent_Medium_value_payments    14509
# Low_spent_Medium_value_payments     11410
# High_spent_Large_value_payments     11288
# High_spent_Small_value_payments      9396
# Low_spent_Large_value_payments       8571
# !@9#%8                               6255
# Name: Payment_Behaviour, dtype: int64

# %%
df_train['Payment_Behaviour'] = df_train['Payment_Behaviour'].replace('!@9#%8', 'Not specified')
df_test['Payment_Behaviour'] = df_test['Payment_Behaviour'].replace('!@9#%8', 'Not specified')

# %%
df_train['Credit_Score'].value_counts()
# Out:
# Standard    44042
# Poor        23966
# Good        14615
# Name: Credit_Score, dtype: int64

# %%
df_train['Delay_from_due_date'] = df_train['Delay_from_due_date'].apply(lambda x: max(0, x))
df_test['Delay_from_due_date'] = df_test['Delay_from_due_date'].apply(lambda x: max(0, x))

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82623 entries, 0 to 82622
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Month                      82623 non-null  int64
#  1   Age                        82623 non-null  float64
#  2   Occupation                 82623 non-null  object
#  3   Annual_Income              82623 non-null  float64
#  4   Monthly_Inhand_Salary      82623 non-null  float64
#  5   Num_Bank_Accounts          82623 non-null  int64
#  6   Num_Credit_Card            82623 non-null  int64
#  7   Interest_Rate              82623 non-null  int64
#  8   Num_of_Loan                82623 non-null  Int64
#  9   Type_of_Loan               82623 non-null  object
#  10  Delay_from_due_date        82623 non-null  int64
#  11  Num_of_Delayed_Payment     82623 non-null  Int64
#  12  Changed_Credit_Limit       82623 non-null  float64
#  13  Num_Credit_Inquiries       82623 non-null  float64
#  14  Credit_Mix                 82623 non-null  object
#  15  Outstanding_Debt           82623 non-null  float64
#  16  Credit_Utilization_Ratio   82623 non-null  float64
#  17  Payment_of_Min_Amount      82623 non-null  object
#  18  Total_EMI_per_month        82623 non-null  float64
#  19  Amount_invested_monthly    82623 non-null  float64
#  20  Payment_Behaviour          82623 non-null  object
#  21  Monthly_Balance            82623 non-null  float64
#  22  Credit_Score               82623 non-null  object
#  23  Credit_History_Age_Months  82623 non-null  Int64
# dtypes: Int64(3), float64(10), int64(5), object(6)
# memory usage: 15.4+ MB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41282 entries, 0 to 41281
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Month                      41282 non-null  int64
#  1   Age                        41282 non-null  float64
#  2   Occupation                 41282 non-null  object
#  3   Annual_Income              41282 non-null  float64
#  4   Monthly_Inhand_Salary      41282 non-null  float64
#  5   Num_Bank_Accounts          41282 non-null  int64
#  6   Num_Credit_Card            41282 non-null  int64
#  7   Interest_Rate              41282 non-null  int64
#  8   Num_of_Loan                41282 non-null  Int64
#  9   Type_of_Loan               41282 non-null  object
#  10  Delay_from_due_date        41282 non-null  int64
#  11  Num_of_Delayed_Payment     41282 non-null  Int64
#  12  Changed_Credit_Limit       41282 non-null  float64
#  13  Num_Credit_Inquiries       41282 non-null  float64
#  14  Credit_Mix                 41282 non-null  object
#  15  Outstanding_Debt           41282 non-null  float64
#  16  Credit_Utilization_Ratio   41282 non-null  float64
#  17  Payment_of_Min_Amount      41282 non-null  object
#  18  Total_EMI_per_month        41282 non-null  float64
#  19  Amount_invested_monthly    41282 non-null  float64
#  20  Payment_Behaviour          41282 non-null  object
#  21  Monthly_Balance            41282 non-null  float64
#  22  Credit_History_Age_Months  41282 non-null  Int64
# dtypes: Int64(3), float64(10), int64(5), object(5)
# memory usage: 7.4+ MB

# %%
df_train.head().T
# Out:
#                                                                            0  \
# Month                                                                      1
# Age                                                                     23.0
# Occupation                                                         Scientist
# Annual_Income                                                       19114.12
# Monthly_Inhand_Salary                                            1824.843333
# Num_Bank_Accounts                                                          3
# Num_Credit_Card                                                            4
# Interest_Rate                                                              3
# Num_of_Loan                                                                4
# Type_of_Loan               Auto Loan, Credit-Builder Loan, Personal Loan,...
# Delay_from_due_date                                                        3
# Num_of_Delayed_Payment                                                     7
# Changed_Credit_Limit                                                  1127.0
# Num_Credit_Inquiries                                                     4.0
# Credit_Mix                                                     Not Specified
# Outstanding_Debt                                                      809.98
# Credit_Utilization_Ratio                                            26.82262
# Payment_of_Min_Amount                                                     No
# Total_EMI_per_month                                                49.574949
# Amount_invested_monthly                                            80.415295
# Payment_Behaviour                            High_spent_Small_value_payments
# Monthly_Balance                                                   312.494089
# Credit_Score                                                            Good
# Credit_History_Age_Months                                                265
#
#                                                                            1  \
# Month                                                                      5
# Age                                                                     23.0
# Occupation                                                         Scientist
# Annual_Income                                                       19114.12
# Monthly_Inhand_Salary                                            1824.843333
# Num_Bank_Accounts                                                          3
# Num_Credit_Card                                                            4
# Interest_Rate                                                              3
# Num_of_Loan                                                                4
# Type_of_Loan               Auto Loan, Credit-Builder Loan, Personal Loan,...
# Delay_from_due_date                                                        6
# Num_of_Delayed_Payment                                                     0
# Changed_Credit_Limit                                                  1127.0
# Num_Credit_Inquiries                                                     4.0
# Credit_Mix                                                              Good
# Outstanding_Debt                                                      809.98
# Credit_Utilization_Ratio                                           24.797347
# Payment_of_Min_Amount                                                     No
# Total_EMI_per_month                                                49.574949
# Amount_invested_monthly                                            41.420153
# Payment_Behaviour                           High_spent_Medium_value_payments
# Monthly_Balance                                                   341.489231
# Credit_Score                                                            Good
# Credit_History_Age_Months                                                269
#
#                                                                            2  \
# Month                                                                      7
# Age                                                                     23.0
# Occupation                                                         Scientist
# Annual_Income                                                       19114.12
# Monthly_Inhand_Salary                                            1824.843333
# Num_Bank_Accounts                                                          3
# Num_Credit_Card                                                            4
# Interest_Rate                                                              3
# Num_of_Loan                                                                4
# Type_of_Loan               Auto Loan, Credit-Builder Loan, Personal Loan,...
# Delay_from_due_date                                                        3
# Num_of_Delayed_Payment                                                     8
# Changed_Credit_Limit                                                  1127.0
# Num_Credit_Inquiries                                                     4.0
# Credit_Mix                                                              Good
# Outstanding_Debt                                                      809.98
# Credit_Utilization_Ratio                                           22.537593
# Payment_of_Min_Amount                                                     No
# Total_EMI_per_month                                                49.574949
# Amount_invested_monthly                                           178.344067
# Payment_Behaviour                             Low_spent_Small_value_payments
# Monthly_Balance                                                   244.565317
# Credit_Score                                                            Good
# Credit_History_Age_Months                                                271
#
#                                                                            3  \
# Month                                                                      8
# Age                                                                     23.0
# Occupation                                                         Scientist
# Annual_Income                                                       19114.12
# Monthly_Inhand_Salary                                            1824.843333
# Num_Bank_Accounts                                                          3
# Num_Credit_Card                                                            4
# Interest_Rate                                                              3
# Num_of_Loan                                                                4
# Type_of_Loan               Auto Loan, Credit-Builder Loan, Personal Loan,...
# Delay_from_due_date                                                        3
# Num_of_Delayed_Payment                                                     6
# Changed_Credit_Limit                                                  1127.0
# Num_Credit_Inquiries                                                     4.0
# Credit_Mix                                                              Good
# Outstanding_Debt                                                      809.98
# Credit_Utilization_Ratio                                           23.933795
# Payment_of_Min_Amount                                                     No
# Total_EMI_per_month                                                49.574949
# Amount_invested_monthly                                            24.785217
# Payment_Behaviour                           High_spent_Medium_value_payments
# Monthly_Balance                                                   358.124168
# Credit_Score                                                        Standard
# Credit_History_Age_Months                                                  0
#
#                                                         4
# Month                                                   1
# Age                                                  28.0
# Occupation                                  Not Specified
# Annual_Income                                    34847.84
# Monthly_Inhand_Salary                         3037.986667
# Num_Bank_Accounts                                       2
# Num_Credit_Card                                         4
# Interest_Rate                                           6
# Num_of_Loan                                             1
# Type_of_Loan                          Credit-Builder Loan
# Delay_from_due_date                                     3
# Num_of_Delayed_Payment                                  4
# Changed_Credit_Limit                                542.0
# Num_Credit_Inquiries                                  2.0
# Credit_Mix                                           Good
# Outstanding_Debt                                   605.03
# Credit_Utilization_Ratio                        24.464031
# Payment_of_Min_Amount                                  No
# Total_EMI_per_month                             18.816215
# Amount_invested_monthly                        104.291825
# Payment_Behaviour          Low_spent_Small_value_payments
# Monthly_Balance                                470.690627
# Credit_Score                                     Standard
# Credit_History_Age_Months                             319

# %%
# Histogram for Age
sns.histplot(df_train['Age'], kde=True )
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# Count Plot for Occupation

sns.countplot(x='Occupation', data=df_train, hue = 'Occupation' , palette = 'pastel')
plt.title('Count of Individuals in Each Occupation')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# Correlation Heatmap
plt.figure(figsize=(12, 10))
numeric_columns = df_train.select_dtypes(include=['float64', 'int64']).columns
corr_matrix = df_train[numeric_columns].corr()
sns.heatmap(corr_matrix, cmap='coolwarm', annot=True, fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
# Bar Plot of Annual Income considwering Credit score
sns.barplot(x='Credit_Score', y='Annual_Income', data=df_train, estimator=np.median)
plt.show()

# %%
sns.scatterplot(x='Monthly_Inhand_Salary', y='Amount_invested_monthly', data=df_train)
plt.show()

# %%
occupation_counts = df_train['Occupation'].value_counts()
plt.pie(occupation_counts, labels=occupation_counts.index, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.show()

# %%
sns.countplot(x='Credit_Mix', data=df_train, order=df_train['Credit_Mix'].value_counts().index , hue = 'Credit_Mix')
plt.show()

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82623 entries, 0 to 82622
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Month                      82623 non-null  int64
#  1   Age                        82623 non-null  float64
#  2   Occupation                 82623 non-null  object
#  3   Annual_Income              82623 non-null  float64
#  4   Monthly_Inhand_Salary      82623 non-null  float64
#  5   Num_Bank_Accounts          82623 non-null  int64
#  6   Num_Credit_Card            82623 non-null  int64
#  7   Interest_Rate              82623 non-null  int64
#  8   Num_of_Loan                82623 non-null  Int64
#  9   Type_of_Loan               82623 non-null  object
#  10  Delay_from_due_date        82623 non-null  int64
#  11  Num_of_Delayed_Payment     82623 non-null  Int64
#  12  Changed_Credit_Limit       82623 non-null  float64
#  13  Num_Credit_Inquiries       82623 non-null  float64
#  14  Credit_Mix                 82623 non-null  object
#  15  Outstanding_Debt           82623 non-null  float64
#  16  Credit_Utilization_Ratio   82623 non-null  float64
#  17  Payment_of_Min_Amount      82623 non-null  object
#  18  Total_EMI_per_month        82623 non-null  float64
#  19  Amount_invested_monthly    82623 non-null  float64
#  20  Payment_Behaviour          82623 non-null  object
#  21  Monthly_Balance            82623 non-null  float64
#  22  Credit_Score               82623 non-null  object
#  23  Credit_History_Age_Months  82623 non-null  Int64
# dtypes: Int64(3), float64(10), int64(5), object(6)
# memory usage: 15.4+ MB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41282 entries, 0 to 41281
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Month                      41282 non-null  int64
#  1   Age                        41282 non-null  float64
#  2   Occupation                 41282 non-null  object
#  3   Annual_Income              41282 non-null  float64
#  4   Monthly_Inhand_Salary      41282 non-null  float64
#  5   Num_Bank_Accounts          41282 non-null  int64
#  6   Num_Credit_Card            41282 non-null  int64
#  7   Interest_Rate              41282 non-null  int64
#  8   Num_of_Loan                41282 non-null  Int64
#  9   Type_of_Loan               41282 non-null  object
#  10  Delay_from_due_date        41282 non-null  int64
#  11  Num_of_Delayed_Payment     41282 non-null  Int64
#  12  Changed_Credit_Limit       41282 non-null  float64
#  13  Num_Credit_Inquiries       41282 non-null  float64
#  14  Credit_Mix                 41282 non-null  object
#  15  Outstanding_Debt           41282 non-null  float64
#  16  Credit_Utilization_Ratio   41282 non-null  float64
#  17  Payment_of_Min_Amount      41282 non-null  object
#  18  Total_EMI_per_month        41282 non-null  float64
#  19  Amount_invested_monthly    41282 non-null  float64
#  20  Payment_Behaviour          41282 non-null  object
#  21  Monthly_Balance            41282 non-null  float64
#  22  Credit_History_Age_Months  41282 non-null  Int64
# dtypes: Int64(3), float64(10), int64(5), object(5)
# memory usage: 7.4+ MB

# %%
df_train.drop(['Month', 'Occupation', 'Type_of_Loan', 'Payment_of_Min_Amount'], axis=1, inplace=True)
df_test.drop(['Month', 'Occupation', 'Type_of_Loan', 'Payment_of_Min_Amount'], axis=1, inplace=True)

# %%
# One-hot encode the object columns
df_train = pd.get_dummies(df_train, columns=['Credit_Mix', 'Payment_Behaviour'])
df_test = pd.get_dummies(df_test, columns=['Credit_Mix', 'Payment_Behaviour'])

# %%
# 'Good' is encoded as 1 and 'Bad' as 0
df_train['Credit_Score'] = df_train['Credit_Score'].map({'Good': 1, 'Bad': 0})

# %%
df_train.shape
# Out:
# (82623, 29)

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41282 entries, 0 to 41281
# Data columns (total 28 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Age                                                 41282 non-null  float64
#  1   Annual_Income                                       41282 non-null  float64
#  2   Monthly_Inhand_Salary                               41282 non-null  float64
#  3   Num_Bank_Accounts                                   41282 non-null  int64
#  4   Num_Credit_Card                                     41282 non-null  int64
#  5   Interest_Rate                                       41282 non-null  int64
#  6   Num_of_Loan                                         41282 non-null  Int64
#  7   Delay_from_due_date                                 41282 non-null  int64
#  8   Num_of_Delayed_Payment                              41282 non-null  Int64
#  9   Changed_Credit_Limit                                41282 non-null  float64
#  10  Num_Credit_Inquiries                                41282 non-null  float64
#  11  Outstanding_Debt                                    41282 non-null  float64
#  12  Credit_Utilization_Ratio                            41282 non-null  float64
#  13  Total_EMI_per_month                                 41282 non-null  float64
#  14  Amount_invested_monthly                             41282 non-null  float64
#  15  Monthly_Balance                                     41282 non-null  float64
#  16  Credit_History_Age_Months                           41282 non-null  Int64
#  17  Credit_Mix_Bad                                      41282 non-null  uint8
#  18  Credit_Mix_Good                                     41282 non-null  uint8
#  19  Credit_Mix_Standard                                 41282 non-null  uint8
#  20  Credit_Mix__                                        41282 non-null  uint8
#  21  Payment_Behaviour_High_spent_Large_value_payments   41282 non-null  uint8
#  22  Payment_Behaviour_High_spent_Medium_value_payments  41282 non-null  uint8
#  23  Payment_Behaviour_High_spent_Small_value_payments   41282 non-null  uint8
#  24  Payment_Behaviour_Low_spent_Large_value_payments    41282 non-null  uint8
#  25  Payment_Behaviour_Low_spent_Medium_value_payments   41282 non-null  uint8
#  26  Payment_Behaviour_Low_spent_Small_value_payments    41282 non-null  uint8
#  27  Payment_Behaviour_Not specified                     41282 non-null  uint8
# dtypes: Int64(3), float64(10), int64(4), uint8(11)
# memory usage: 5.9 MB
